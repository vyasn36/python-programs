# %%
#bill is above 500
bill=float(input("enter total bill amount:"))
if bill>500:
    print("you are eligible for coopan!")
# Out:
# enter total bill amount: 600
# you are eligible for coopan!

# %%
#bill is < 500
bill=float(input("enter total bill:"))
if bill<500:
    print(" sorry you are not eligible for coopan")
# Out:
# enter total bill: 100
#  sorry you are not eligible for coopan

# %%
#bill is >= 500 (congratulations)
bill=float(input("enter billl amount"))
if bill>=500:
    print("congratulations you won 5% extra discount")
# Out:
# enter billl amount 400

# %%
#bill is <=500 (bater luck next time)
bill=float(input("enter billl amount"))
if bill<=500:
    print("bater luck next time")
# Out:
# enter billl amount 200
# bater luck next time

# %%
#name start with A
name = input("Enter your name: ")
if name.startswith("A"):
    print("Group A")
# Out:
# Enter your name:  Amitt
# Group A

# %%
# name start with A or not
name = input("Enter your name: ")
if name.startswith("A"):
    print("Group A")
else:
    print("not in the group A")
# Out:
# Enter your name:  amitt
# not in the group A

# %%
# name end with a
name = input("Enter your name: ")
if name.endswith("a"):
    print("Ends with 'a'")
else:
    print("Does not end with 'a'")
# Out:
# Enter your name:  Nishant
# Does not end with 'a'

# %%
# name end with n
name = input("Enter your name: ")
if name.endswith("n"):
    print("Ends with 'n'")
else:
    print(" End with 'n'")
# Out:
# Enter your name:  Nishan
# Ends with 'n'

# %%
# name is longer then 5 chatares
name=input("enter your name:")
if len(name)>5:
    print("long name")
# Out:
# enter your name: Nishant
# long name

# %%
# vowel ,consonant
name=input("enter your name:")
if name.startswith("AEIOU"):
    print("vowel")
else:
    print("consonant")
# Out:
# enter your name: Nishant
# consonant

# %%
# vowel ,consonant
name=input("enter your name:")
if name.endswith("AEIOU"):
    print("vowel")
else:
    print("consonant")
# Out:
# enter your name: nisha
# consonant

# %%
#Check if a Number is Even
number=int(input("enter a number:"))
if number%2==0:
    print("this is an even number")
# Out:
# enter a number: 20
# this is an even number

# %%
#Check if a Student Scored Full Marks in a Quiz
mark=int(input("enter your obtain mark:"))
full_mark=int(input("enter quiz total mark:"))
if mark==full_mark:
    print("student socre full mark")
# Out:
# enter your obtain mark: 50
# enter quiz total mark: 50
# student socre full mark

# %%
#Check if a Number is Positive
number=int(input("enter number:"))
if number >0:
    print("number is positive")
# Out:
# enter number: 5
# number is positive

# %%
#Check if a Number is negative
number=int(input("enter numbae:"))
if number<0:
    print("number is negative")
# Out:
# enter numbae: -3
# number is negative

# %%
#Check if a Number is negative / positive
number=int(input("enter numbe:"))
if number>0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# enter numbe: -2
# number is negative

# %%
#Check if Email Contains “@”
email = input("Enter your email: ")

if "." and "@" in email:
    print("Email is valid")
else:
    print("Email is invalid")
# Out:
# Enter your email:  vyasn36@gmail.com
# Email is valid

# %%
#Check If Salary is Above Threshold
salary=float(input("enter your salary:"))
threshold_salary=float(input("enter threshold salary:"))
if threshold_salary<salary:
    print("good salary")
else:
    print("not good salary")
# Out:
# enter your salary: 60000
# enter threshold salary: 50000
# good salary

# %%
#Temperature Advisory
temperature=float(input("enter todays temprature:"))
if temperature<40:
    print("normal temperature.")
if temperature>40:  
        print("high temperature.")
# Out:
# enter todays temprature: 43
# high temperature.

# %%
#login 
username = input("Enter your username: ")
if username == "admin":
    print("Welcome, admin!")
else:
    print("Access denied.")
# Out:
# Enter your username:  admin
# Welcome, admin!

# %%
#log in 
username = input("Enter your username: ")
if username == "admin":
    print("Welcome, admin!")
else:
    print("Access denied.")
# Out:
# Enter your username:  Nishant
# Access denied.

# %% [markdown]
# ### Budget Warning
# budget=float(input("enter your budget:"))
# if budget>90000:
#     print(" over budget")
# else:
#     print("under budjet")

# %% [markdown]
# #Income Tax
# income=float(input("enter your income:"))
# if income<1200000:
#     print("no tex")
# else:
#     print("30% tex")

# %%
#Income Tax 
income=float(input("enter your income:"))
if income<1200000:
    print("no tex")
else:
    print("30% tex")
# Out:
# enter your income: 1500000
# 30% tex

# %%
#sum
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
sum = a + b
print("Sum:", sum)
# Out:
# Enter first number:  25
# Enter second number:  15
# Sum: 40.0

# %%
#sum
a1=float(input("enter first number:"))
a2=float(input("enter second number:"))
a3=float(input("enter third number:"))
sum=(a1+a2+a3)
print("sum:", sum )
# Out:
# enter first number: 2
# enter second number: 5
# enter third number: 8
# sum: 15.0

# %%
#difference
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
difference = a - b
print("Difference:", difference)
# Out:
# Enter first number:  10
# Enter second number:  5
# Difference: 5.0

# %%
#Multiplication
a1=float(input("enter first number:"))
a2=float(input("enter second number:"))
a3=float(input("enter third number:"))
Multiplication=(a1*a2*a3)
print("Multiplication:",Multiplication)
# Out:
# enter first number: 2
# enter second number: 2
# enter third number: 2
# Multiplication: 8.0

# %%
# total price 
price = float(input("Enter price per item: "))
quantity = float(input("Enter quantity: "))
total = price * quantity
print("Total cost:", total)
# Out:
# Enter price per item:  500
# Enter quantity:  8
# Total cost: 4000.0

# %%
#percentage
marks_obtained = float(input("Enter total marks obtained: "))
total_marks = float(input("Enter total possible marks: "))
percentage = (marks_obtained / total_marks) * 100
print("Percentage:", percentage, "%")
# Out:
# Enter total marks obtained:  900
# Enter total possible marks:  1100
# Percentage: 81.81818181818183 %

# %%
#profit
cost_price=float(input("enter cost price:"))
selling_price=float(input("enter selling price:"))
profit=selling_price-cost_price
print("profit:",profit)
# Out:
# enter cost price: 250
# enter selling price: 400
# profit: 150.0

# %%
# find loss
cost_price=float(input("enter cost price:"))
selling_price=float(input("enter selling price:"))
loss=cost_price-selling_price
print("loss:",loss)
# Out:
# enter cost price: 500
# enter selling price: 400
# loss: 100.0

# %%
#Floor Division
a = int(input("Enter dividend: "))
b = int(input("Enter divisor: "))
floor_div = a // b
print("Floor Division:", floor_div)
# Out:
# Enter dividend:  10
# Enter divisor:  8
# Floor Division: 1

# %%
# remainder
a = int(input("Enter dividend: "))
b = int(input("Enter divisor: "))
remainder = a % b
print("Remainder:", remainder)
# Out:
# Enter dividend:  10
# Enter divisor:  8
# Remainder: 2

# %%
#simple intrest
p = float(input("Enter Principal amount: "))
r = float(input("Enter Rate of Interest: "))
t = float(input("Enter Time (in years): "))
si = (p * r * t) / 100
print("Simple Interest:", si)
# Out:
# Enter Principal amount:  40000
# Enter Rate of Interest:  8
# Enter Time (in years):  2
# Simple Interest: 6400.0

# %%
# base and power 
base = float(input("Enter the base number: "))
power = float(input("Enter the power: "))
result = base ** power
print("Result:", result)
# Out:
# Enter the base number:  8
# Enter the power:  9
# Result: 134217728.0

# %%
#GST
price=float(input("product price:"))
gst=float(input("gst%:"))
gst_amount=price*gst/100
bill=gst_amount+price
print(f"price:{bill}")
# Out:
# product price: 200
# gst%: 5
# price:210.0

# %%
#simple intrest
p=float(input("enter amount:"))
r=float(input("enter rate of intrest:"))
t=float(input("enter time(in year):"))
simple_intrest=(p*r*t)/100
print(f"simple intrest:{simple_intrest}")
# Out:
# enter amount: 8000
# enter rate of intrest: 4
# enter time(in year): 1
# simple intrest:320.0

# %%
#add name 
first_name=input("enter first name:")
second_name=input("enter second name:")
full_name= first_name+ " " +second_name
print("full name:",full_name)
# Out:
# enter first name: nishant
# enter second name: vyas
# full name: nishant vyas
